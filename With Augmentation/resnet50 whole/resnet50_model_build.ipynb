# %%
# !pip install tensorflow kagglehub
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.9)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<2.0.0,>=1.23.5->tensorflow) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2.0.0,>=1.23.5->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2.0.0,>=1.23.5->tensorflow) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<2.0.0,>=1.23.5->tensorflow) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<2.0.0,>=1.23.5->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<2.0.0,>=1.23.5->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import mixed_precision

# %%
# Set mixed precision policy
mixed_precision.set_global_policy('mixed_float16')
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
random_rotation = tf.keras.layers.RandomRotation(0.2, dtype=tf.float32)
random_zoom = tf.keras.layers.RandomZoom(0.2, dtype=tf.float32)
random_flip = tf.keras.layers.RandomFlip("horizontal", dtype=tf.float32)
random_contrast = tf.keras.layers.RandomContrast(0.3, dtype=tf.float32)

# %%
def augment_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    def apply_augmentation(img):
        choice = tf.random.uniform(shape=[], minval=0, maxval=7, dtype=tf.int32)
        
        # All augmentation functions now return float32
        def apply_flip(): return random_flip(img)
        def apply_brightness(): return tf.image.random_brightness(img, 0.4)
        def apply_contrast(): return random_contrast(img)
        def apply_rotation(): return random_rotation(tf.expand_dims(img, 0))[0]
        def apply_zoom(): return random_zoom(tf.expand_dims(img, 0))[0]
        def apply_hue(): return tf.image.random_hue(img, 0.3)
        def apply_saturation(): return tf.image.random_saturation(img, 0.6, 1.6)
            
        return tf.switch_case(choice, [
            apply_flip, apply_brightness, apply_contrast, apply_rotation,
            apply_zoom, apply_hue, apply_saturation
        ])

    # 50% chance to apply augmentation
    image = tf.cond(
        tf.random.uniform(()) < 0.5,
        lambda: apply_augmentation(image),
        lambda: image
    )
    
    image = preprocess_input(image)
    return tf.cast(image, tf.float16), label

# %%
# Load dataset using tf.data
AUTOTUNE = tf.data.AUTOTUNE

# %%
def create_dataset(directory, augment=False):
    ds = tf.keras.utils.image_dataset_from_directory(
        directory,
        image_size=(256, 256),
        batch_size=None,
        shuffle=augment,
        seed=42 if augment else None
    )
    if augment:
        ds = ds.map(augment_image, num_parallel_calls=AUTOTUNE)
    else:
        ds = ds.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE)
    return ds.batch(64).prefetch(AUTOTUNE)

# %%
# Download dataset
import kagglehub
dataset_path = kagglehub.dataset_download("manjilkarki/deepfake-and-real-images")
base_dir = os.path.join(dataset_path, "Dataset")

train_ds = create_dataset(os.path.join(base_dir, "Train"), augment=True)
val_ds = create_dataset(os.path.join(base_dir, "Validation"))
test_ds = create_dataset(os.path.join(base_dir, "Test"))
# Out:
# Found 140002 files belonging to 2 classes.
# Found 39428 files belonging to 2 classes.
# Found 10905 files belonging to 2 classes.

# %%
# Model setup
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
base_model.trainable = False

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32')(x)

model = tf.keras.Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_auc', mode='max', factor=0.5, patience=2, min_lr=1e-7, verbose=1
)
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "best_model.keras", monitor='val_auc', mode='max', save_best_only=True, verbose=1
)
earlystop_cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', mode='max', patience=5, restore_best_weights=True, verbose=1
)

# %%
# Phase 1: Frozen base
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# %%
history_phase1 = model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr]
)
# Out:
# Epoch 1/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7533 - auc: 0.8353 - loss: 4.1433
# Epoch 1: val_auc improved from -inf to 0.90865, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 579s 257ms/step - accuracy: 0.7533 - auc: 0.8353 - loss: 4.1424 - val_accuracy: 0.8276 - val_auc: 0.9086 - val_loss: 0.7838 - learning_rate: 1.0000e-04
# Epoch 2/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8185 - auc: 0.9026 - loss: 0.6950
# Epoch 2: val_auc improved from 0.90865 to 0.91364, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 484s 221ms/step - accuracy: 0.8185 - auc: 0.9026 - loss: 0.6950 - val_accuracy: 0.8275 - val_auc: 0.9136 - val_loss: 0.5311 - learning_rate: 1.0000e-04
# Epoch 3/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8245 - auc: 0.9090 - loss: 0.5125
# Epoch 3: val_auc improved from 0.91364 to 0.91663, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 482s 220ms/step - accuracy: 0.8245 - auc: 0.9090 - loss: 0.5125 - val_accuracy: 0.8292 - val_auc: 0.9166 - val_loss: 0.4759 - learning_rate: 1.0000e-04
# Epoch 4/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8299 - auc: 0.9132 - loss: 0.4654
# Epoch 4: val_auc improved from 0.91663 to 0.91925, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 488s 223ms/step - accuracy: 0.8299 - auc: 0.9132 - loss: 0.4654 - val_accuracy: 0.8310 - val_auc: 0.9193 - val_loss: 0.4561 - learning_rate: 1.0000e-04
# Epoch 5/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8298 - auc: 0.9139 - loss: 0.4503
# Epoch 5: val_auc did not improve from 0.91925
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 494s 226ms/step - accuracy: 0.8298 - auc: 0.9139 - loss: 0.4503 - val_accuracy: 0.8366 - val_auc: 0.9175 - val_loss: 0.4393 - learning_rate: 1.0000e-04
# Epoch 6/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8301 - auc: 0.9136 - loss: 0.4435
# Epoch 6: val_auc improved from 0.91925 to 0.92030, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 483s 221ms/step - accuracy: 0.8301 - auc: 0.9136 - loss: 0.4435 - val_accuracy: 0.8395 - val_auc: 0.9203 - val_loss: 0.4294 - learning_rate: 1.0000e-04
# Epoch 7/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8339 - auc: 0.9167 - loss: 0.4331
# Epoch 7: val_auc improved from 0.92030 to 0.92107, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 481s 220ms/step - accuracy: 0.8339 - auc: 0.9167 - loss: 0.4331 - val_accuracy: 0.8413 - val_auc: 0.9211 - val_loss: 0.4239 - learning_rate: 1.0000e-04
# Epoch 8/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8331 - auc: 0.9161 - loss: 0.4315
# Epoch 8: val_auc did not improve from 0.92107
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 487s 223ms/step - accuracy: 0.8331 - auc: 0.9161 - loss: 0.4315 - val_accuracy: 0.8382 - val_auc: 0.9166 - val_loss: 0.4303 - learning_rate: 1.0000e-04
# Epoch 9/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8345 - auc: 0.9169 - loss: 0.4279
# Epoch 9: val_auc improved from 0.92107 to 0.92134, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 627s 286ms/step - accuracy: 0.8345 - auc: 0.9169 - loss: 0.4279 - val_accuracy: 0.8410 - val_auc: 0.9213 - val_loss: 0.4189 - learning_rate: 1.0000e-04
# Epoch 10/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8350 - auc: 0.9176 - loss: 0.4244
# Epoch 10: val_auc did not improve from 0.92134
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 558s 255ms/step - accuracy: 0.8350 - auc: 0.9176 - loss: 0.4244 - val_accuracy: 0.8357 - val_auc: 0.9178 - val_loss: 0.4271 - learning_rate: 1.0000e-04
# Epoch 11/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8360 - auc: 0.9179 - loss: 0.4224
# Epoch 11: val_auc did not improve from 0.92134
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 487s 222ms/step - accuracy: 0.8360 - auc: 0.9179 - loss: 0.4224 - val_accuracy: 0.8211 - val_auc: 0.9163 - val_loss: 0.4494 - learning_rate: 1.0000e-04
# Epoch 12/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8421 - auc: 0.9238 - loss: 0.4034
# Epoch 12: val_auc improved from 0.92134 to 0.92416, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 490s 224ms/step - accuracy: 0.8421 - auc: 0.9238 - loss: 0.4034 - val_accuracy: 0.8447 - val_auc: 0.9242 - val_loss: 0.3969 - learning_rate: 5.0000e-05
# Epoch 13/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8445 - auc: 0.9267 - loss: 0.3886
# Epoch 13: val_auc improved from 0.92416 to 0.92813, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 483s 221ms/step - accuracy: 0.8445 - auc: 0.9267 - loss: 0.3886 - val_accuracy: 0.8481 - val_auc: 0.9281 - val_loss: 0.3863 - learning_rate: 5.0000e-05
# Epoch 14/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8480 - auc: 0.9290 - loss: 0.3809
# Epoch 14: val_auc improved from 0.92813 to 0.92857, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 485s 222ms/step - accuracy: 0.8480 - auc: 0.9290 - loss: 0.3809 - val_accuracy: 0.8398 - val_auc: 0.9286 - val_loss: 0.3994 - learning_rate: 5.0000e-05
# Epoch 15/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8486 - auc: 0.9298 - loss: 0.3785
# Epoch 15: val_auc did not improve from 0.92857
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 491s 224ms/step - accuracy: 0.8486 - auc: 0.9298 - loss: 0.3785 - val_accuracy: 0.8496 - val_auc: 0.9283 - val_loss: 0.3837 - learning_rate: 5.0000e-05
# Epoch 16/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8500 - auc: 0.9299 - loss: 0.3774
# Epoch 16: val_auc improved from 0.92857 to 0.93001, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 490s 224ms/step - accuracy: 0.8500 - auc: 0.9299 - loss: 0.3774 - val_accuracy: 0.8488 - val_auc: 0.9300 - val_loss: 0.3836 - learning_rate: 5.0000e-05
# Epoch 17/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8516 - auc: 0.9305 - loss: 0.3760
# Epoch 17: val_auc did not improve from 0.93001
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 490s 224ms/step - accuracy: 0.8516 - auc: 0.9305 - loss: 0.3760 - val_accuracy: 0.8468 - val_auc: 0.9279 - val_loss: 0.3878 - learning_rate: 5.0000e-05
# Epoch 18/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8494 - auc: 0.9299 - loss: 0.3771
# Epoch 18: val_auc did not improve from 0.93001
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 487s 223ms/step - accuracy: 0.8494 - auc: 0.9299 - loss: 0.3771 - val_accuracy: 0.8467 - val_auc: 0.9289 - val_loss: 0.3864 - learning_rate: 5.0000e-05
# Epoch 19/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8560 - auc: 0.9350 - loss: 0.3635
# Epoch 19: val_auc improved from 0.93001 to 0.93231, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 485s 222ms/step - accuracy: 0.8560 - auc: 0.9350 - loss: 0.3635 - val_accuracy: 0.8506 - val_auc: 0.9323 - val_loss: 0.3762 - learning_rate: 2.5000e-05
# Epoch 20/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8600 - auc: 0.9380 - loss: 0.3532
# Epoch 20: val_auc improved from 0.93231 to 0.93333, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 485s 222ms/step - accuracy: 0.8600 - auc: 0.9380 - loss: 0.3532 - val_accuracy: 0.8506 - val_auc: 0.9333 - val_loss: 0.3739 - learning_rate: 2.5000e-05
# Epoch 21/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8614 - auc: 0.9391 - loss: 0.3485
# Epoch 21: val_auc did not improve from 0.93333
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 485s 222ms/step - accuracy: 0.8614 - auc: 0.9391 - loss: 0.3485 - val_accuracy: 0.8491 - val_auc: 0.9324 - val_loss: 0.3747 - learning_rate: 2.5000e-05
# Epoch 22/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8615 - auc: 0.9403 - loss: 0.3445
# Epoch 22: val_auc improved from 0.93333 to 0.93339, saving model to best_model.keras
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 499s 228ms/step - accuracy: 0.8615 - auc: 0.9403 - loss: 0.3445 - val_accuracy: 0.8541 - val_auc: 0.9334 - val_loss: 0.3655 - learning_rate: 2.5000e-05
# Epoch 23/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8667 - auc: 0.9430 - loss: 0.3368
# Epoch 23: val_auc improved from 0.93339 to 0.93496, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 504s 230ms/step - accuracy: 0.8667 - auc: 0.9430 - loss: 0.3368 - val_accuracy: 0.8559 - val_auc: 0.9350 - val_loss: 0.3589 - learning_rate: 1.2500e-05
# Epoch 24/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8701 - auc: 0.9454 - loss: 0.3291
# Epoch 24: val_auc improved from 0.93496 to 0.93759, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 505s 231ms/step - accuracy: 0.8701 - auc: 0.9454 - loss: 0.3291 - val_accuracy: 0.8600 - val_auc: 0.9376 - val_loss: 0.3508 - learning_rate: 1.2500e-05
# Epoch 25/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8716 - auc: 0.9469 - loss: 0.3241
# Epoch 25: val_auc did not improve from 0.93759
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 507s 231ms/step - accuracy: 0.8716 - auc: 0.9469 - loss: 0.3241 - val_accuracy: 0.8596 - val_auc: 0.9352 - val_loss: 0.3544 - learning_rate: 1.2500e-05
# Epoch 26/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8746 - auc: 0.9482 - loss: 0.3202
# Epoch 26: val_auc did not improve from 0.93759
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 510s 233ms/step - accuracy: 0.8746 - auc: 0.9482 - loss: 0.3202 - val_accuracy: 0.8592 - val_auc: 0.9368 - val_loss: 0.3532 - learning_rate: 1.2500e-05
# Epoch 27/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8747 - auc: 0.9490 - loss: 0.3175
# Epoch 27: val_auc improved from 0.93759 to 0.93821, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 504s 230ms/step - accuracy: 0.8747 - auc: 0.9490 - loss: 0.3175 - val_accuracy: 0.8611 - val_auc: 0.9382 - val_loss: 0.3478 - learning_rate: 6.2500e-06
# Epoch 28/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8762 - auc: 0.9496 - loss: 0.3147
# Epoch 28: val_auc did not improve from 0.93821
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 483s 221ms/step - accuracy: 0.8762 - auc: 0.9496 - loss: 0.3147 - val_accuracy: 0.8607 - val_auc: 0.9377 - val_loss: 0.3478 - learning_rate: 6.2500e-06
# Epoch 29/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8782 - auc: 0.9506 - loss: 0.3119
# Epoch 29: val_auc did not improve from 0.93821
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 487s 223ms/step - accuracy: 0.8782 - auc: 0.9506 - loss: 0.3119 - val_accuracy: 0.8605 - val_auc: 0.9380 - val_loss: 0.3487 - learning_rate: 6.2500e-06
# Epoch 30/30
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8792 - auc: 0.9522 - loss: 0.3073
# Epoch 30: val_auc improved from 0.93821 to 0.93865, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 485s 221ms/step - accuracy: 0.8792 - auc: 0.9522 - loss: 0.3073 - val_accuracy: 0.8634 - val_auc: 0.9386 - val_loss: 0.3442 - learning_rate: 3.1250e-06
# Restoring model weights from the end of the best epoch: 30.

# %%
# Evaluation
model.load_weights("best_model.keras")
test_loss, test_acc, test_auc = model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.8078 - auc: 0.4273 - loss: 0.4677
# Test Loss: 0.6804
# Test Accuracy: 0.7353
# Test AUC: 0.8240

# %%
# Phase 2: Fine-tuning
base_model.trainable = True
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# %%
history_phase2 = model.fit(
    train_ds,
    epochs=15,
    validation_data=val_ds,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr]
)
# Out:
# Epoch 1/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9356 - auc: 0.9825 - loss: 0.1857
# Epoch 1: val_auc improved from 0.93865 to 0.99487, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1053s 444ms/step - accuracy: 0.9356 - auc: 0.9825 - loss: 0.1857 - val_accuracy: 0.9700 - val_auc: 0.9949 - val_loss: 0.1102 - learning_rate: 1.0000e-05
# Epoch 2/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9810 - auc: 0.9981 - loss: 0.0757
# Epoch 2: val_auc improved from 0.99487 to 0.99582, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 920s 420ms/step - accuracy: 0.9810 - auc: 0.9981 - loss: 0.0757 - val_accuracy: 0.9713 - val_auc: 0.9958 - val_loss: 0.1021 - learning_rate: 1.0000e-05
# Epoch 3/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9876 - auc: 0.9993 - loss: 0.0526
# Epoch 3: val_auc improved from 0.99582 to 0.99701, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 925s 423ms/step - accuracy: 0.9876 - auc: 0.9993 - loss: 0.0526 - val_accuracy: 0.9787 - val_auc: 0.9970 - val_loss: 0.0787 - learning_rate: 1.0000e-05
# Epoch 4/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9914 - auc: 0.9995 - loss: 0.0398
# Epoch 4: val_auc improved from 0.99701 to 0.99733, saving model to best_model.keras
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 930s 425ms/step - accuracy: 0.9914 - auc: 0.9995 - loss: 0.0398 - val_accuracy: 0.9818 - val_auc: 0.9973 - val_loss: 0.0670 - learning_rate: 1.0000e-05
# Epoch 5/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0303
# Epoch 5: val_auc did not improve from 0.99733
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 910s 416ms/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0303 - val_accuracy: 0.9827 - val_auc: 0.9969 - val_loss: 0.0647 - learning_rate: 1.0000e-05
# Epoch 6/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9944 - auc: 0.9998 - loss: 0.0248
# Epoch 6: val_auc did not improve from 0.99733
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 915s 418ms/step - accuracy: 0.9944 - auc: 0.9998 - loss: 0.0248 - val_accuracy: 0.9794 - val_auc: 0.9957 - val_loss: 0.0763 - learning_rate: 1.0000e-05
# Epoch 7/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9960 - auc: 0.9998 - loss: 0.0190
# Epoch 7: val_auc did not improve from 0.99733
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 912s 417ms/step - accuracy: 0.9960 - auc: 0.9998 - loss: 0.0190 - val_accuracy: 0.9837 - val_auc: 0.9968 - val_loss: 0.0612 - learning_rate: 5.0000e-06
# Epoch 8/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9967 - auc: 0.9998 - loss: 0.0165
# Epoch 8: val_auc did not improve from 0.99733
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 917s 419ms/step - accuracy: 0.9967 - auc: 0.9998 - loss: 0.0165 - val_accuracy: 0.9835 - val_auc: 0.9970 - val_loss: 0.0591 - learning_rate: 5.0000e-06
# Epoch 9/15
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9974 - auc: 0.9998 - loss: 0.0135
# Epoch 9: val_auc did not improve from 0.99733
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 919s 420ms/step - accuracy: 0.9974 - auc: 0.9998 - loss: 0.0135 - val_accuracy: 0.9852 - val_auc: 0.9969 - val_loss: 0.0565 - learning_rate: 2.5000e-06
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# Evaluation
model.load_weights("best_model.keras")
test_loss, test_acc, test_auc = model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 18s 107ms/step - accuracy: 0.9338 - auc: 0.4717 - loss: 0.2856
# Test Loss: 0.8210
# Test Accuracy: 0.8386
# Test AUC: 0.9047
